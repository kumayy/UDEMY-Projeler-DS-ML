# %% [markdown]
# # **PANDAS**

# %% [markdown]
# # Data Frame Operasyonları
#
# Sh*t is About to Get Real
# ### Import Files
# Çok zor ama velevki komut çalışmadı
#
#     !pip install xlrd
#     !pip install openpyxl
#
# bunları bi çalıştırıp koşturuver.
# (editörü açıp kapatmayı unutma.)
# ### Import Yöntemleri:
#
# 1. İçe aktarılacak dosya ve not defteri aynı dosyaının içinndeyse:
#
#         df = pd.read_csv("data.xxx")
#
# 2. Farklı dosyalarda ise:
#
#         df = pd.read_csv("C:\\Users\\mbatu\\Desktop\\Kumay\\DS 101\\PANDAS\\data.xxx")
#
#     **VEYA**
#     relative path ile
#
#         df = pd.read_csv("../data/data.xxx")

# %%
import pandas as pd

# %%
df = pd.read_csv("heroes.csv")

# %%
df
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0    Naruto Uzumaki      good            50        80     32          80
# 1          Deadpool   neutral            50        15     30         100
# 2           Man-Bat   neutral            38        18     50          70
# 3      Ra's Al Ghul       bad           100        28     32          42
# 4          Stardust      good            88        85    100         110
# ..              ...       ...           ...       ...    ...         ...
# 407           Blink      good            50         8     20          28
# 408           Venom       bad            75        57     65          84
# 409       Wolverine      good            55        32     38         100
# 410    Chuck Norris      good            50        80     47          56
# 411        Superman      good           100       100    100         100
#
#      Power  Combat  Total
# 0      100     100    442
# 1      100     100    395
# ...

# %%
df.head()
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  Naruto Uzumaki      good            50        80     32          80    100
# 1        Deadpool   neutral            50        15     30         100    100
# 2         Man-Bat   neutral            38        18     50          70     33
# 3    Ra's Al Ghul       bad           100        28     32          42     27
# 4        Stardust      good            88        85    100         110    100
#
#    Combat  Total
# 0     100    442
# 1     100    395
# 2      30    239
# 3     100    329
# 4      85    568

# %%
df.tail()
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 407         Blink      good            50         8     20          28     55
# 408         Venom       bad            75        57     65          84     79
# 409     Wolverine      good            55        32     38         100     44
# 410  Chuck Norris      good            50        80     47          56     42
# 411      Superman      good           100       100    100         100     94
#
#      Combat  Total
# 407      64    225
# 408      84    444
# 409     100    369
# 410      99    374
# 411      85    579

# %%
df.head(6)
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  Naruto Uzumaki      good            50        80     32          80    100
# 1        Deadpool   neutral            50        15     30         100    100
# 2         Man-Bat   neutral            38        18     50          70     33
# 3    Ra's Al Ghul       bad           100        28     32          42     27
# 4        Stardust      good            88        85    100         110    100
# 5        Punisher      good            50        16     23          28     22
#
#    Combat  Total
# 0     100    442
# 1     100    395
# 2      30    239
# 3     100    329
# 4      85    568
# 5     100    239

# %%
df.tail(2)
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 410  Chuck Norris      good            50        80     47          56     42
# 411      Superman      good           100       100    100         100     94
#
#      Combat  Total
# 410      99    374
# 411      85    579

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412 entries, 0 to 411
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          412 non-null    object
#  1   Alignment     410 non-null    object
#  2   Intelligence  412 non-null    int64
#  3   Strength      412 non-null    int64
#  4   Speed         412 non-null    int64
#  5   Durability    412 non-null    int64
#  6   Power         412 non-null    int64
#  7   Combat        412 non-null    int64
#  8   Total         412 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 29.1+ KB

# %%
df.describe()
# Out:
#        Intelligence    Strength       Speed  Durability       Power  \
# count    412.000000  412.000000  412.000000  412.000000  412.000000
# mean      62.334951   40.876214   37.856796   59.043689   57.441748
# std       21.002246   32.535987   22.796922   30.425179   27.372780
# min        6.000000    1.000000    1.000000    1.000000    0.000000
# 25%       50.000000   10.000000   23.000000   28.000000   35.000000
# 50%       63.000000   32.000000   33.000000   58.000000   58.500000
# 75%       75.000000   75.500000   50.000000   90.000000   76.250000
# max      113.000000  100.000000  100.000000  120.000000  100.000000
#
#            Combat       Total
# count  412.000000  412.000000
# mean    60.878641  318.432039
# std     23.050560  106.384432
# min      6.000000   60.000000
# 25%     42.000000  239.000000
# 50%     64.000000  306.000000
# 75%     80.000000  388.000000
# max    101.000000  581.000000

# %%
df.describe().transpose()
# Out:
#               count        mean         std   min    25%    50%     75%    max
# Intelligence  412.0   62.334951   21.002246   6.0   50.0   63.0   75.00  113.0
# Strength      412.0   40.876214   32.535987   1.0   10.0   32.0   75.50  100.0
# Speed         412.0   37.856796   22.796922   1.0   23.0   33.0   50.00  100.0
# Durability    412.0   59.043689   30.425179   1.0   28.0   58.0   90.00  120.0
# Power         412.0   57.441748   27.372780   0.0   35.0   58.5   76.25  100.0
# Combat        412.0   60.878641   23.050560   6.0   42.0   64.0   80.00  101.0
# Total         412.0  318.432039  106.384432  60.0  239.0  306.0  388.00  581.0

# %%
len(df)
# Out:
# 412

# %%
df.index
# Out:
# RangeIndex(start=0, stop=412, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Alignment', 'Intelligence', 'Strength', 'Speed', 'Durability',
#        'Power', 'Combat', 'Total'],
#       dtype='object')

# %%
df["Name"]
# Out:
# 0      Naruto Uzumaki
# 1            Deadpool
# 2             Man-Bat
# 3        Ra's Al Ghul
# 4            Stardust
#             ...
# 407             Blink
# 408             Venom
# 409         Wolverine
# 410      Chuck Norris
# 411          Superman
# Name: Name, Length: 412, dtype: object

# %%
df["Strength"]
# Out:
# 0       80
# 1       15
# 2       18
# 3       28
# 4       85
#       ...
# 407      8
# 408     57
# 409     32
# 410     80
# 411    100
# Name: Strength, Length: 412, dtype: int64

# %%
type(df["Combat"])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Power', 'Combat', 'Total']]
# Out:
#      Power  Combat  Total
# 0      100     100    442
# 1      100     100    395
# 2       33      30    239
# 3       27     100    329
# 4      100      85    568
# ..     ...     ...    ...
# 407     55      64    225
# 408     79      84    444
# 409     44     100    369
# 410     42      99    374
# 411     94      85    579
#
# [412 rows x 3 columns]

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Sütun Ekleme

# %%
df.columns
# Out:
# Index(['Name', 'Alignment', 'Intelligence', 'Strength', 'Speed', 'Durability',
#        'Power', 'Combat', 'Total'],
#       dtype='object')

# %%
df["Attack"] = df["Strength"] + df["Combat"]
df.head()
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  Naruto Uzumaki      good            50        80     32          80    100
# 1        Deadpool   neutral            50        15     30         100    100
# 2         Man-Bat   neutral            38        18     50          70     33
# 3    Ra's Al Ghul       bad           100        28     32          42     27
# 4        Stardust      good            88        85    100         110    100
#
#    Combat  Total  Attack
# 0     100    442     180
# 1     100    395     115
# 2      30    239      48
# 3     100    329     128
# 4      85    568     170

# %%
df["brain muscle ratio"] = round(df["Intelligence"] / df["Strength"], 2)
df.head()
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  Naruto Uzumaki      good            50        80     32          80    100
# 1        Deadpool   neutral            50        15     30         100    100
# 2         Man-Bat   neutral            38        18     50          70     33
# 3    Ra's Al Ghul       bad           100        28     32          42     27
# 4        Stardust      good            88        85    100         110    100
#
#    Combat  Total  Attack  brain muscle ratio
# 0     100    442     180                0.62
# 1     100    395     115                3.33
# 2      30    239      48                2.11
# 3     100    329     128                3.57
# 4      85    568     170                1.04

# %%
# df["hp ratio %"] = round(df["hp ratio %"], 2)
# bu da makbuldür

# %% [markdown]
# ___
# ___

# %% [markdown]
# ### .drop()

# %%
# df.drop("brain muscle ratio")
# Axis yok

# %%
# help(df.drop)

# %%
df.drop("brain muscle ratio", axis=1).head()
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  Naruto Uzumaki      good            50        80     32          80    100
# 1        Deadpool   neutral            50        15     30         100    100
# 2         Man-Bat   neutral            38        18     50          70     33
# 3    Ra's Al Ghul       bad           100        28     32          42     27
# 4        Stardust      good            88        85    100         110    100
#
#    Combat  Total  Attack
# 0     100    442     180
# 1     100    395     115
# 2      30    239      48
# 3     100    329     128
# 4      85    568     170

# %%
df.head()
# Hala burada
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  Naruto Uzumaki      good            50        80     32          80    100
# 1        Deadpool   neutral            50        15     30         100    100
# 2         Man-Bat   neutral            38        18     50          70     33
# 3    Ra's Al Ghul       bad           100        28     32          42     27
# 4        Stardust      good            88        85    100         110    100
#
#    Combat  Total  Attack  brain muscle ratio
# 0     100    442     180                0.62
# 1     100    395     115                3.33
# 2      30    239      48                2.11
# 3     100    329     128                3.57
# 4      85    568     170                1.04

# %%
df = df.drop("brain muscle ratio", axis=1)

# %%
df.head()
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  Naruto Uzumaki      good            50        80     32          80    100
# 1        Deadpool   neutral            50        15     30         100    100
# 2         Man-Bat   neutral            38        18     50          70     33
# 3    Ra's Al Ghul       bad           100        28     32          42     27
# 4        Stardust      good            88        85    100         110    100
#
#    Combat  Total  Attack
# 0     100    442     180
# 1     100    395     115
# 2      30    239      48
# 3     100    329     128
# 4      85    568     170

# %%
df.drop("Attack", axis=1, inplace=True)
# Arka arkaya 2 kere çalıştırmayı dene ve sence hata ne onu söyle

# %%
df.head()
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  Naruto Uzumaki      good            50        80     32          80    100
# 1        Deadpool   neutral            50        15     30         100    100
# 2         Man-Bat   neutral            38        18     50          70     33
# 3    Ra's Al Ghul       bad           100        28     32          42     27
# 4        Stardust      good            88        85    100         110    100
#
#    Combat  Total
# 0     100    442
# 1     100    395
# 2      30    239
# 3     100    329
# 4      85    568

# %%
df.drop([4], axis= 0).head()
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  Naruto Uzumaki      good            50        80     32          80    100
# 1        Deadpool   neutral            50        15     30         100    100
# 2         Man-Bat   neutral            38        18     50          70     33
# 3    Ra's Al Ghul       bad           100        28     32          42     27
# 5        Punisher      good            50        16     23          28     22
#
#    Combat  Total
# 0     100    442
# 1     100    395
# 2      30    239
# 3     100    329
# 5     100    239

# %%
df.drop([3]).head()
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  Naruto Uzumaki      good            50        80     32          80    100
# 1        Deadpool   neutral            50        15     30         100    100
# 2         Man-Bat   neutral            38        18     50          70     33
# 4        Stardust      good            88        85    100         110    100
# 5        Punisher      good            50        16     23          28     22
#
#    Combat  Total
# 0     100    442
# 1     100    395
# 2      30    239
# 4      85    568
# 5     100    239

# %% [markdown]
# ___
# ___

# %% [markdown]
# ### DataFrame İndex Operasyonları

# %%
df.set_index("Name").head()
# Out:
#                Alignment  Intelligence  Strength  Speed  Durability  Power  \
# Name
# Naruto Uzumaki      good            50        80     32          80    100
# Deadpool         neutral            50        15     30         100    100
# Man-Bat          neutral            38        18     50          70     33
# Ra's Al Ghul         bad           100        28     32          42     27
# Stardust            good            88        85    100         110    100
#
#                 Combat  Total
# Name
# Naruto Uzumaki     100    442
# Deadpool           100    395
# Man-Bat             30    239
# Ra's Al Ghul       100    329
# Stardust            85    568

# %%
df.reset_index().head()
# Out:
#    index            Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0      0  Naruto Uzumaki      good            50        80     32          80
# 1      1        Deadpool   neutral            50        15     30         100
# 2      2         Man-Bat   neutral            38        18     50          70
# 3      3    Ra's Al Ghul       bad           100        28     32          42
# 4      4        Stardust      good            88        85    100         110
#
#    Power  Combat  Total
# 0    100     100    442
# 1    100     100    395
# 2     33      30    239
# 3     27     100    329
# 4    100      85    568

# %%
df.iloc[2]
# Out:
# Name            Man-Bat
# Alignment       neutral
# Intelligence         38
# Strength             18
# Speed                50
# Durability           70
# Power                33
# Combat               30
# Total               239
# Name: 2, dtype: object

# %%
df.loc[9]
# Out:
# Name            Flash
# Alignment        good
# Intelligence       63
# Strength           10
# Speed             100
# Durability         50
# Power              57
# Combat             32
# Total             312
# Name: 9, dtype: object

# %%
df.loc[9:11]
# isim temelli çalışır
# Out:
#      Name Alignment  Intelligence  Strength  Speed  Durability  Power  Combat  \
# 9   Flash      good            63        10    100          50     57      32
# 10  Skaar      good            50        85     27          90     62      85
# 11  Cable      good            88        48     23          56    100      80
#
#     Total
# 9     312
# 10    399
# 11    395

# %%
df.iloc[25:35]
# int temelli çalışır.
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 25  Batgirl IV      good            69        12     27          56     42
# 26    Bullseye       bad            50        11     25          70     20
# 27       Match       bad            75        95     83          85     90
# 28         Sif      good            50        57     25          52     19
# 29       Spyke      good            50        12     17          60     41
# 30     Zatanna      good            75        10     23          28    100
# 31   Man-Thing      good            50        32      8         100     98
# 32  Elastigirl      good            38        32     12          90     20
# 33        Goku      good            56       100     75          90    100
# 34     Mach-IV       bad            75        36     60          84     60
#
#     Combat  Total
# 25     100    306
# 26      70    246
# 27      70    498
# 28      70    273
# 29      30    210
# 30      56    292
# ...

# %%
df = df.set_index("Name")

# %%
df
# Out:
#                Alignment  Intelligence  Strength  Speed  Durability  Power  \
# Name
# Naruto Uzumaki      good            50        80     32          80    100
# Deadpool         neutral            50        15     30         100    100
# Man-Bat          neutral            38        18     50          70     33
# Ra's Al Ghul         bad           100        28     32          42     27
# Stardust            good            88        85    100         110    100
# ...                  ...           ...       ...    ...         ...    ...
# Blink               good            50         8     20          28     55
# Venom                bad            75        57     65          84     79
# Wolverine           good            55        32     38         100     44
# Chuck Norris        good            50        80     47          56     42
# Superman            good           100       100    100         100     94
#
#                 Combat  Total
# Name
# ...

# %%
df.loc["Spider-Man"]
# Out:
# Alignment       good
# Intelligence      88
# Strength          55
# Speed             60
# Durability        74
# Power             58
# Combat            85
# Total            420
# Name: Spider-Man, dtype: object

# %%
df.loc[["Wolverine","Wonder Woman","Goku","Joker"]]
# Out:
#              Alignment  Intelligence  Strength  Speed  Durability  Power  \
# Name
# Wolverine         good            55        32     38         100     44
# Wonder Woman      good            88       100     50         100     42
# Goku              good            56       100     75          90    100
# Joker              bad           100        10     12          56     22
#
#               Combat  Total
# Name
# Wolverine        100    369
# Wonder Woman     100    480
# Goku             100    521
# Joker             90    290

# %%
# df.iloc["Joker"]

# %%
df = df.reset_index()
df.head()
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0  Naruto Uzumaki      good            50        80     32          80    100
# 1        Deadpool   neutral            50        15     30         100    100
# 2         Man-Bat   neutral            38        18     50          70     33
# 3    Ra's Al Ghul       bad           100        28     32          42     27
# 4        Stardust      good            88        85    100         110    100
#
#    Combat  Total
# 0     100    442
# 1     100    395
# 2      30    239
# 3     100    329
# 4      85    568

# %%
df
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0    Naruto Uzumaki      good            50        80     32          80
# 1          Deadpool   neutral            50        15     30         100
# 2           Man-Bat   neutral            38        18     50          70
# 3      Ra's Al Ghul       bad           100        28     32          42
# 4          Stardust      good            88        85    100         110
# ..              ...       ...           ...       ...    ...         ...
# 407           Blink      good            50         8     20          28
# 408           Venom       bad            75        57     65          84
# 409       Wolverine      good            55        32     38         100
# 410    Chuck Norris      good            50        80     47          56
# 411        Superman      good           100       100    100         100
#
#      Power  Combat  Total
# 0      100     100    442
# 1      100     100    395
# ...

# %% [markdown]
# ---
# ---

# %% [markdown]
# # https://www.youtube.com/watch?v=BCiNjLq0S60
